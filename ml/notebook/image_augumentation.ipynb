# %%
#prepare image and augment
import glob
import os
from PIL import Image

# %%
sample = "../data/raw_images/sample_jpg/"

# %%
ls "../data/raw_images/sample_jpg/"
# Out:
# 0_000d65be-5bb9-44f5-83f7-77697204fdd2.jpg
# 0_0ca75887-8f27-4778-9bbf-4c91393d49dc.jpg
# 0_0d6ad635-ea21-475a-bab4-e91e1780ede8.jpg
# 0_0d6ca089-526e-4932-a555-24c45d5ff168.jpg
# 0_0dd3c76b-57ef-4f90-a152-ff43647ff2ac.jpg
# 1_0_04df947d-f385-4bd8-baea-8e96ffabf23f.jpg
# 1_0_1b1490cd-3645-4e82-acef-615b13667b67.jpg
# 1_0_1d2cb236-8c47-4a33-a07d-2dfaec14c933.jpg
# 1_0_2b507134-2948-46ac-82e9-d2dcb37e5fcc.jpg
# 1_0_2ea1942a-7310-4799-84f5-efc910e16472.jpg
# 2_0_0a5f4700-91c8-45c2-8bfc-fa7d08f5677d.jpg
# 2_0_1b8d2821-efbc-4b7c-a0e6-551be6368ddf.jpg
# 2_0_1cebb62e-54d9-4366-b934-3fc761453953.jpg
# 2_0_3a1cd0db-dfff-4744-9154-be323d1cb970.jpg
# 2_0_3df7cd8c-39cd-4dd1-ad18-7cf95fed7011.jpg
# 3_0_04b50f5f-7f5d-41c5-8f50-97fbeaf20437.jpg
# 3_0_2db84138-08dc-4056-b8ba-1ed53521ac93.jpg
# 3_0_3dc01541-20a8-43c5-aa1d-45b34de37211.jpg
# 3_0_4f07aca9-a3a4-4090-8493-ac11decd2a8d.jpg
# 3_0_6dfac279-8dc7-434b-8e8c-6a5e5e0038bb.jpg
# 4_0_0481f8c1-4ceb-46f7-98b7-f0446e621086.jpg
# ...

# %%
Input_dir='../data/raw_images/fine'
Output_dir = '../data/raw_images/output'

# %%
from numpy import expand_dims
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# %matplotlib inline

img = load_img('../data/raw_images/sample_jpg/0_0ca75887-8f27-4778-9bbf-4c91393d49dc.jpg')
data = img_to_array(img)
samples = expand_dims(data, 0)

#Image_Augmentation_Parameters
Shift_Range = 0
Brightness_Range = 0
Rotation_Angle=0
ZoomRange = 0.8

# datagen = ImageDataGenerator(width_shift_range=[-Shift_Range,Shift_Range], 
#                              height_shift_range=[-Shift_Range,Shift_Range],
#                              brightness_range=[1-Brightness_Range,1+Brightness_Range],
#                              zoom_range=[1-ZoomRange, 1+ZoomRange],
#                              rotation_range=Rotation_Angle)

datagen = ImageDataGenerator(featurewise_center=False,
                                 featurewise_std_normalization=False,
                                 rotation_range=.3,
                                 width_shift_range=0.4,
                                 height_shift_range=0.0,)
it = datagen.flow(samples, batch_size=1)

for i in range(9):
    pyplot.subplot(330 + 1 + i)
    batch = it.next()
    image = batch[0].astype('uint8')
    pyplot.imshow(image)

pyplot.show()

# %%
from numpy import expand_dims
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# %matplotlib inline

img = load_img('../data/raw_images/sample_jpg/1_0_04df947d-f385-4bd8-baea-8e96ffabf23f.jpg')
data = img_to_array(img)
samples = expand_dims(data, 0)

#Image_Augmentation_Parameters
Shift_Range = 0
Brightness_Range = 0
Rotation_Angle=0
ZoomRange = 0.8

# datagen = ImageDataGenerator(width_shift_range=[-Shift_Range,Shift_Range], 
#                              height_shift_range=[-Shift_Range,Shift_Range],
#                              brightness_range=[1-Brightness_Range,1+Brightness_Range],
#                              zoom_range=[1-ZoomRange, 1+ZoomRange],
#                              rotation_range=Rotation_Angle)
datagen = ImageDataGenerator(featurewise_center=True,
                                 featurewise_std_normalization=True,
                                 rotation_range=0.3,
                                 width_shift_range=0.4,
                                 height_shift_range=0.2, )
it = datagen.flow(samples, batch_size=1)

for i in range(9):
    pyplot.subplot(330 + 1 + i)
    batch = it.next()
    image = batch[0].astype('uint8')
    pyplot.imshow(image)

pyplot.show()

# %%
from numpy import expand_dims
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# %matplotlib inline

img = load_img('../data/raw_images/sample_jpg/2_0_1cebb62e-54d9-4366-b934-3fc761453953.jpg')
data = img_to_array(img)
samples = expand_dims(data, 0)

#Image_Augmentation_Parameters
Shift_Range = 0
Brightness_Range = 0
Rotation_Angle=0
ZoomRange = 0.8

# datagen = ImageDataGenerator(width_shift_range=[-Shift_Range,Shift_Range], 
#                              height_shift_range=[-Shift_Range,Shift_Range],
#                              brightness_range=[1-Brightness_Range,1+Brightness_Range],
#                              zoom_range=[1-ZoomRange, 1+ZoomRange],
#                              rotation_range=Rotation_Angle)
datagen = ImageDataGenerator(featurewise_center=False,
                                 featurewise_std_normalization=False,
                                 rotation_range=5,
                                 width_shift_range=0.1,
                                 height_shift_range=0.1, )
it = datagen.flow(samples, batch_size=1)

for i in range(9):
    pyplot.subplot(330 + 1 + i)
    batch = it.next()
    image = batch[0].astype('uint8')
    pyplot.imshow(image)

pyplot.show()

# %%
from numpy import expand_dims
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# %matplotlib inline

img = load_img('../data/raw_images/sample_jpg/3_0_04b50f5f-7f5d-41c5-8f50-97fbeaf20437.jpg')
data = img_to_array(img)
samples = expand_dims(data, 0)

#Image_Augmentation_Parameters
Shift_Range = 0
Brightness_Range = 0
Rotation_Angle=0
ZoomRange = 0.8

# datagen = ImageDataGenerator(width_shift_range=[-Shift_Range,Shift_Range], 
#                              height_shift_range=[-Shift_Range,Shift_Range],
#                              brightness_range=[1-Brightness_Range,1+Brightness_Range],
#                              zoom_range=[1-ZoomRange, 1+ZoomRange],
#                              rotation_range=Rotation_Angle)
datagen = ImageDataGenerator(featurewise_center=False,
                                 featurewise_std_normalization=False,
                                 rotation_range=5,
                                 width_shift_range=0.1,
                                 height_shift_range=0.1, )
it = datagen.flow(samples, batch_size=1)

for i in range(9):
    pyplot.subplot(330 + 1 + i)
    batch = it.next()
    image = batch[0].astype('uint8')
    pyplot.imshow(image)

pyplot.show()

# %%
from numpy import expand_dims
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# %matplotlib inline

img = load_img('../data/raw_images/sample_jpg/4_0_156aa32b-c9a6-401e-9d67-5190fde82ce7.jpg')
data = img_to_array(img)
samples = expand_dims(data, 0)

#Image_Augmentation_Parameters
Shift_Range = 0
Brightness_Range = 0
Rotation_Angle=0
ZoomRange = 0.8

# datagen = ImageDataGenerator(width_shift_range=[-Shift_Range,Shift_Range], 
#                              height_shift_range=[-Shift_Range,Shift_Range],
#                              brightness_range=[1-Brightness_Range,1+Brightness_Range],
#                              zoom_range=[1-ZoomRange, 1+ZoomRange],
#                              rotation_range=Rotation_Angle)
datagen = ImageDataGenerator(featurewise_center=False,
                                 featurewise_std_normalization=False,
                                 rotation_range=5,
                                 width_shift_range=0.1,
                                 height_shift_range=0.1, )
it = datagen.flow(samples, batch_size=1)

for i in range(9):
    pyplot.subplot(330 + 1 + i)
    batch = it.next()
    image = batch[0].astype('uint8')
    pyplot.imshow(image)

pyplot.show()

# %%
from numpy import expand_dims
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# %matplotlib inline

img = load_img('../data/raw_images/sample_jpg/5_0_e866b67e-6de0-41c3-83d4-dd52cf3e02c5.jpg')
data = img_to_array(img)
samples = expand_dims(data, 0)

#Image_Augmentation_Parameters
Shift_Range = 0
Brightness_Range = 0
Rotation_Angle=0
ZoomRange = 0.8

# datagen = ImageDataGenerator(width_shift_range=[-Shift_Range,Shift_Range], 
#                              height_shift_range=[-Shift_Range,Shift_Range],
#                              brightness_range=[1-Brightness_Range,1+Brightness_Range],
#                              zoom_range=[1-ZoomRange, 1+ZoomRange],
#                              rotation_range=Rotation_Angle)
datagen = ImageDataGenerator(featurewise_center=False,
                                 featurewise_std_normalization=False,
                                 rotation_range=5,
                                 width_shift_range=0.1,
                                 height_shift_range=0.1, )
it = datagen.flow(samples, batch_size=1)

for i in range(9):
    pyplot.subplot(330 + 1 + i)
    batch = it.next()
    image = batch[0].astype('uint8')
    pyplot.imshow(image)

pyplot.show()

# %%
from numpy import expand_dims
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# %matplotlib inline

img = load_img('../data/raw_images/sample_jpg/6_0_6195ea8a-9617-4099-8232-b010dc08cf8d.jpg')
data = img_to_array(img)
samples = expand_dims(data, 0)

#Image_Augmentation_Parameters
Shift_Range = 0
Brightness_Range = 0
Rotation_Angle=0
ZoomRange = 0.8

# datagen = ImageDataGenerator(width_shift_range=[-Shift_Range,Shift_Range], 
#                              height_shift_range=[-Shift_Range,Shift_Range],
#                              brightness_range=[1-Brightness_Range,1+Brightness_Range],
#                              zoom_range=[1-ZoomRange, 1+ZoomRange],
#                              rotation_range=Rotation_Angle)
datagen = ImageDataGenerator(featurewise_center=False,
                                 featurewise_std_normalization=False,
                                 rotation_range=5,
                                 width_shift_range=0.1,
                                 height_shift_range=0.1, )
it = datagen.flow(samples, batch_size=1)

for i in range(9):
    pyplot.subplot(330 + 1 + i)
    batch = it.next()
    image = batch[0].astype('uint8')
    pyplot.imshow(image)

pyplot.show()

# %%
from numpy import expand_dims
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# %matplotlib inline

img = load_img('../data/raw_images/sample_jpg/7_0_b7585c69-dfc9-47cb-b67b-8f1385c62445.jpg')
data = img_to_array(img)
samples = expand_dims(data, 0)

#Image_Augmentation_Parameters
Shift_Range = 0
Brightness_Range = 0
Rotation_Angle=0
ZoomRange = 0.8

# datagen = ImageDataGenerator(width_shift_range=[-Shift_Range,Shift_Range], 
#                              height_shift_range=[-Shift_Range,Shift_Range],
#                              brightness_range=[1-Brightness_Range,1+Brightness_Range],
#                              zoom_range=[1-ZoomRange, 1+ZoomRange],
#                              rotation_range=Rotation_Angle)
datagen = ImageDataGenerator(featurewise_center=False,
                                 featurewise_std_normalization=False,
                                 rotation_range=5,
                                 width_shift_range=0.1,
                                 height_shift_range=0.1,)
it = datagen.flow(samples, batch_size=1)

for i in range(9):
    pyplot.subplot(330 + 1 + i)
    batch = it.next()
    image = batch[0].astype('uint8')
    pyplot.imshow(image)

pyplot.show()

# %%
from numpy import expand_dims
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# %matplotlib inline

img = load_img('../data/raw_images/sample_jpg/8_0_a1ac0194-b9aa-4b34-ab0e-8034e86b7ecb.jpg')
data = img_to_array(img)
samples = expand_dims(data, 0)

#Image_Augmentation_Parameters
Shift_Range = 0
Brightness_Range = 0
Rotation_Angle=0
ZoomRange = 0.8

# datagen = ImageDataGenerator(width_shift_range=[-Shift_Range,Shift_Range], 
#                              height_shift_range=[-Shift_Range,Shift_Range],
#                              brightness_range=[1-Brightness_Range,1+Brightness_Range],
#                              zoom_range=[1-ZoomRange, 1+ZoomRange],
#                              rotation_range=Rotation_Angle)
datagen = ImageDataGenerator(featurewise_center=False,
                                 featurewise_std_normalization=False,
                                 rotation_range=5,
                                 width_shift_range=0.1,
                                 height_shift_range=0.1,)
it = datagen.flow(samples, batch_size=1)

for i in range(9):
    pyplot.subplot(330 + 1 + i)
    batch = it.next()
    image = batch[0].astype('uint8')
    pyplot.imshow(image)

pyplot.show()

# %%
from numpy import expand_dims
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# %matplotlib inline

img = load_img('../data/raw_images/sample_jpg/9_0_2770a19e-bd67-4c1a-888d-e8f34be91608.jpg')
data = img_to_array(img)
samples = expand_dims(data, 0)

#Image_Augmentation_Parameters
Shift_Range = 0
Brightness_Range = 0
Rotation_Angle=0
ZoomRange = 0.8

# datagen = ImageDataGenerator(width_shift_range=[-Shift_Range,Shift_Range], 
#                              height_shift_range=[-Shift_Range,Shift_Range],
#                              brightness_range=[1-Brightness_Range,1+Brightness_Range],
#                              zoom_range=[1-ZoomRange, 1+ZoomRange],
#                              rotation_range=Rotation_Angle)
datagen = ImageDataGenerator(featurewise_center=False,
                                 featurewise_std_normalization=False,
#                                  height_shift_range=[-Shift_Range,Shift_Range],
                                 rotation_range=5,
                                 width_shift_range=0.1,
                                 height_shift_range=0.1,)
it = datagen.flow(samples, batch_size=1)

for i in range(9):
    pyplot.subplot(330 + 1 + i)
    batch = it.next()
    image = batch[0].astype('uint8')
    pyplot.imshow(image)

pyplot.show()

# %% [markdown]
# - Don't apply horizontal or vertical flips
